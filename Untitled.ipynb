# %% [markdown]
# # This project aims to build a model to predict grades of pupils based on performances in certain subjects

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# build the dataframe
#np.random.seed(0)
df = pd.DataFrame ({'student_id' : np.arange(1,202), 'age':np.random.randint(6,10,201),'basic_science':np.random.randint(30,60,201),\
'literacy':np.random.randint(20,60,201), 'quantitative_reasoning' :np.random.randint(28,60,201), "literature" :np.random.randint(28,60,201),\
"ict" : np.random.randint(35,60,201), "ettiquette": np.random.randint(40,60,201), "history": np.random.randint(40,60,201),\
                   "music": np.random.randint(40,60,201)})

# %%
df.student_id= df.student_id.apply(lambda x: 'student_id'+'_'+str(x))

# %%
df['total_grade'] = df.apply(lambda x: x['basic_science'] +  x.literacy + x.quantitative_reasoning \
    + x.literature + x.ict + x.ettiquette + x.history + x.music, axis = 1)

# %%
df
# Out:
#          student_id  age  basic_science  literacy  quantitative_reasoning  \
# 0      student_id_1    9             36        47                      38
# 1      student_id_2    6             30        21                      32
# 2      student_id_3    7             30        43                      53
# 3      student_id_4    6             55        24                      50
# 4      student_id_5    7             48        35                      38
# ..              ...  ...            ...       ...                     ...
# 196  student_id_197    6             46        34                      59
# 197  student_id_198    7             48        37                      32
# 198  student_id_199    8             31        22                      33
# 199  student_id_200    7             50        59                      31
# 200  student_id_201    8             54        23                      33
#
#      literature  ict  ettiquette  history  music  total_grade
# 0            51   49          57       54     59          391
# 1            42   48          50       59     43          325
# 2            35   44          46       49     51          351
# 3            28   35          52       42     47          333
# 4            51   52          56       42     47          369
# ..          ...  ...         ...      ...    ...          ...
# 196          56   42          48       50     41          376
# 197          33   48          50       52     55          355
# 198          41   55          56       49     48          335
# 199          28   38          48       40     48          342
# 200          32   37          59       44     53          335
#
# [201 rows x 11 columns]

# %%
# age distributiion
df_age = df.age.value_counts()

# %%
fig,ax = plt.subplots(figsize = (6,10))
df_age.plot(kind = 'pie', explode=[0.04, 0.05, 0.05, 0.05],autopct='%1.1f%%')
ax.set(title = 'Age Distribution');

# %%
df.describe()
# Out:
#               age  basic_science    literacy  quantitative_reasoning  \
# count  201.000000     201.000000  201.000000              201.000000
# mean     7.527363      45.452736   38.084577               43.328358
# std      1.100226       9.065815   12.025299                8.898407
# min      6.000000      30.000000   20.000000               28.000000
# 25%      7.000000      37.000000   27.000000               36.000000
# 50%      7.000000      47.000000   36.000000               43.000000
# 75%      9.000000      54.000000   48.000000               51.000000
# max      9.000000      59.000000   59.000000               59.000000
#
#        literature         ict  ettiquette     history       music  total_grade
# count   201.00000  201.000000  201.000000  201.000000  201.000000   201.000000
# mean     42.39801   47.626866   49.512438   49.676617   49.044776   365.124378
# std       8.71727    7.413169    5.351738    5.799129    5.716029    23.413232
# min      28.00000   35.000000   40.000000   40.000000   40.000000   311.000000
# 25%      35.00000   41.000000   45.000000   45.000000   44.000000   348.000000
# 50%      42.00000   48.000000   50.000000   50.000000   49.000000   366.000000
# 75%      50.00000   54.000000   54.000000   55.000000   54.000000   382.000000
# max      59.00000   59.000000   59.000000   59.000000   59.000000   421.000000

# %%
fig,ax = plt.subplots(figsize = (14,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
