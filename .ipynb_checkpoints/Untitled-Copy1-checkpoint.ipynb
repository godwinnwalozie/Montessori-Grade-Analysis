# %% [markdown]
# # Analysis of performance of pupils in montessori school

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# build the dataframe
#np.random.seed(0)
df = pd.DataFrame ({'student_id' : np.arange(1,202), 'age':np.random.randint(6,10,201),'basic_science':np.random.randint(30,60,201),\
'literacy':np.random.randint(20,60,201), 'quantitative_reasoning' :np.random.randint(28,60,201), "literature" :np.random.randint(28,60,201),\
"ict" : np.random.randint(35,60,201), "ettiquette": np.random.randint(40,60,201), "history": np.random.randint(40,60,201),\
                   "music": np.random.randint(40,60,201)})

# %%
df.student_id= df.student_id.apply(lambda x: 'student_id'+'_'+str(x))

# %%
df['total_grade'] = df.apply(lambda x: x['basic_science'] +  x.literacy + x.quantitative_reasoning \
    + x.literature + x.ict + x.ettiquette + x.history + x.music, axis = 1)

# %%
df
# Out:
#          student_id  age  basic_science  literacy  quantitative_reasoning  \
# 0      student_id_1    9             51        52                      54
# 1      student_id_2    7             35        24                      44
# 2      student_id_3    9             39        27                      45
# 3      student_id_4    9             59        23                      35
# 4      student_id_5    6             51        31                      33
# ..              ...  ...            ...       ...                     ...
# 196  student_id_197    9             52        40                      53
# 197  student_id_198    9             47        45                      37
# 198  student_id_199    6             35        20                      31
# 199  student_id_200    7             54        41                      31
# 200  student_id_201    7             52        43                      53
#
#      literature  ict  ettiquette  history  music  total_grade
# 0            41   36          46       58     53          391
# 1            48   39          40       57     49          336
# 2            28   44          52       45     53          333
# 3            46   47          58       46     56          370
# 4            59   46          55       47     42          364
# ..          ...  ...         ...      ...    ...          ...
# 196          47   35          53       40     51          371
# 197          38   50          44       46     54          361
# 198          45   59          58       41     43          332
# 199          57   57          52       41     42          375
# 200          55   52          56       44     58          413
#
# [201 rows x 11 columns]

# %%
# age distributiion
df_age = df.age.value_counts()

# %%
fig,ax = plt.subplots(figsize = (6,10))
df_age.plot(kind = 'pie', explode=[0.04, 0.05, 0.05, 0.05],autopct='%1.1f%%')
ax.set(title = 'Age Distribution');

# %%
df.describe()
# Out:
#               age  basic_science    literacy  quantitative_reasoning  \
# count  201.000000     201.000000  201.000000              201.000000
# mean     7.487562      45.442786   40.164179               43.343284
# std      1.183678       8.800452   11.649803                9.149129
# min      6.000000      30.000000   20.000000               28.000000
# 25%      6.000000      37.000000   29.000000               35.000000
# 50%      7.000000      46.000000   41.000000               43.000000
# 75%      9.000000      53.000000   50.000000               51.000000
# max      9.000000      59.000000   59.000000               59.000000
#
#        literature         ict  ettiquette     history       music  total_grade
# count  201.000000  201.000000  201.000000  201.000000  201.000000   201.000000
# mean    44.333333   47.288557   49.363184   49.388060   49.358209   368.681592
# std      9.029581    7.345496    5.878983    5.852235    6.253882    24.487713
# min     28.000000   35.000000   40.000000   40.000000   40.000000   313.000000
# 25%     36.000000   41.000000   45.000000   44.000000   43.000000   352.000000
# 50%     45.000000   47.000000   50.000000   49.000000   49.000000   368.000000
# 75%     51.000000   53.000000   54.000000   55.000000   55.000000   387.000000
# max     59.000000   59.000000   59.000000   59.000000   59.000000   424.000000

# %%
fig,ax = plt.subplots(figsize = (14,8))
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>
