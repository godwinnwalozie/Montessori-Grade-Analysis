# %% [markdown]
# # A test dataset to analyse performance of montessori pupils

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import dython

# %%
# build the dataframe
#np.random.seed(42)
df = pd.DataFrame ({'student_id' : np.arange(1,202), 'age':np.random.randint(6,10,201),'basic_science':np.random.randint(30,60,201),\
'literacy':np.random.randint(20,60,201), 'quantitative_reasoning' :np.random.randint(28,60,201), "literature" :np.random.randint(28,60,201),\
"ict" : np.random.randint(35,60,201), "ettiquette": np.random.randint(40,60,201), "history": np.random.randint(40,60,201),\
                   "music": np.random.randint(40,60,201)})

# %%
df.student_id= df.student_id.apply(lambda x: 'student_id'+'_'+str(x))

# %%
df['total_grade'] = df.apply(lambda x: x['basic_science'] +  x.literacy + x.quantitative_reasoning \
    + x.literature + x.ict + x.ettiquette + x.history + x.music, axis = 1)

# %%
df
# Out:
#          student_id  age  basic_science  literacy  quantitative_reasoning  \
# 0      student_id_1    6             30        35                      48
# 1      student_id_2    7             52        50                      29
# 2      student_id_3    9             54        26                      28
# 3      student_id_4    9             56        36                      34
# 4      student_id_5    9             33        37                      32
# ..              ...  ...            ...       ...                     ...
# 196  student_id_197    8             32        45                      29
# 197  student_id_198    8             59        52                      37
# 198  student_id_199    9             34        53                      28
# 199  student_id_200    8             41        29                      59
# 200  student_id_201    8             48        37                      30
#
#      literature  ict  ettiquette  history  music  total_grade
# 0            36   56          42       54     53          354
# 1            44   54          41       43     42          355
# 2            45   36          47       51     58          345
# 3            37   45          41       40     41          330
# 4            54   35          45       48     40          324
# ..          ...  ...         ...      ...    ...          ...
# 196          32   35          55       59     58          345
# 197          57   55          48       45     54          407
# 198          50   39          45       55     49          353
# 199          41   37          42       40     52          341
# 200          32   35          47       51     41          321
#
# [201 rows x 11 columns]

# %%
# age distributiion
df_age = df.age.value_counts()

# %%
fig,ax = plt.subplots(figsize = (6,10))
df_age.plot(kind = 'pie', explode=[0.04, 0.05, 0.05, 0.05],autopct='%1.1f%%')
ax.set(title = 'Age Distribution');

# %%
df.describe()
# Out:
#               age  basic_science    literacy  quantitative_reasoning  \
# count  201.000000     201.000000  201.000000              201.000000
# mean     7.462687      45.064677   39.223881               43.900498
# std      1.144487       8.862889   11.834890                8.589531
# min      6.000000      30.000000   20.000000               28.000000
# 25%      6.000000      38.000000   30.000000               37.000000
# 50%      7.000000      46.000000   38.000000               43.000000
# 75%      9.000000      52.000000   49.000000               51.000000
# max      9.000000      59.000000   59.000000               59.000000
#
#        literature         ict  ettiquette    history       music  total_grade
# count  201.000000  201.000000  201.000000  201.00000  201.000000   201.000000
# mean    43.437811   47.114428   49.094527   49.00995   49.636816   366.482587
# std      9.077299    7.710502    5.919123    5.80430    5.623383    22.629206
# min     28.000000   35.000000   40.000000   40.00000   40.000000   318.000000
# 25%     36.000000   40.000000   44.000000   44.00000   45.000000   350.000000
# 50%     43.000000   47.000000   49.000000   49.00000   49.000000   365.000000
# 75%     51.000000   54.000000   55.000000   54.00000   55.000000   383.000000
# max     59.000000   59.000000   59.000000   59.00000   59.000000   419.000000

# %%
fig,ax = plt.subplots(figsize = (14,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df_grade = df.loc[:,['student_id','total_grade']]
df_grade.sort_values('total_grade', ascending = False)
# Out:
#          student_id  total_grade
# 165  student_id_166          419
# 77    student_id_78          417
# 193  student_id_194          415
# 28    student_id_29          413
# 4      student_id_5          412
# ..              ...          ...
# 153  student_id_154          324
# 41    student_id_42          322
# 146  student_id_147          322
# 29    student_id_30          321
# 136  student_id_137          318
#
# [201 rows x 2 columns]

# %%
# top ten student
fig,ax = plt.subplots(figsize = (10,6))
sns.barplot(data = df_grade[:10], y = df_grade.sort_values('total_grade', ascending = False).student_id[:10]\
            ,  x = df_grade.sort_values('total_grade', ascending = False).total_grade[:10])
# Out:
# <AxesSubplot:xlabel='total_grade', ylabel='student_id'>

# %%
df.quantitative_reasoning.corr(df.basic_science)
# Out:
# 0.051183067343279424

# %%
from dython.nominal import associations
associations(df.loc[:,['quantitative_reasoning','basic_science']])
# Out:
# {'corr':                         quantitative_reasoning  basic_science
#  quantitative_reasoning                1.000000       0.051183
#  basic_science                         0.051183       1.000000,
#  'ax': <AxesSubplot:>}

# %%
associations(df.corr(), figsize = (14,9))
# Out:
# {'corr':                              age  basic_science  literacy  \
#  age                     1.000000      -0.128842 -0.209557
#  basic_science          -0.128842       1.000000  0.189060
#  literacy               -0.209557       0.189060  1.000000
#  quantitative_reasoning  0.032193       0.059013  0.164811
#  literature             -0.108203      -0.001554 -0.175009
#  ict                     0.044263       0.146923  0.131761
#  ettiquette             -0.257328      -0.031525 -0.052344
#  history                -0.220684      -0.303991 -0.171194
#  music                  -0.293529      -0.228946 -0.207558
#  total_grade            -0.445832       0.505101  0.654665
#
#                          quantitative_reasoning  literature       ict  \
#  age                                   0.032193   -0.108203  0.044263
#  basic_science                         0.059013   -0.001554  0.146923
#  literacy                              0.164811   -0.175009  0.131761
#  quantitative_reasoning                1.000000   -0.009202 -0.279651
#  literature                           -0.009202    1.000000 -0.218842
#  ict                                  -0.279651   -0.218842  1.000000
#  ettiquette                           -0.070161    0.010017  0.048287
#  history                              -0.165091   -0.002255 -0.078123
#  music                                -0.097145   -0.251331 -0.253109
#  total_grade                           0.362419    0.199063  0.240576
#
#                          ettiquette   history     music  total_grade
#  age                      -0.257328 -0.220684 -0.293529    -0.445832
#  basic_science            -0.031525 -0.303991 -0.228946     0.505101
#  literacy                 -0.052344 -0.171194 -0.207558     0.654665
#  quantitative_reasoning   -0.070161 -0.165091 -0.097145     0.362419
#  literature                0.010017 -0.002255 -0.251331     0.199063
#  ict                       0.048287 -0.078123 -0.253109     0.240576
#  ettiquette                1.000000  0.106605 -0.093426     0.242112
#  history                   0.106605  1.000000 -0.036068    -0.040794
#  music                    -0.093426 -0.036068  1.000000    -0.245608
#  total_grade               0.242112 -0.040794 -0.245608     1.000000  ,
#  'ax': <AxesSubplot:>}
